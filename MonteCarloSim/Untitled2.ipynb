# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import csv
import argparse as ap
from scipy.fftpack import fft
from scipy.fftpack import fftfreq
from scipy.stats import linregress as linregress
import matplotlib.animation as manimation

plt.rc('text', usetex=True)

# %%
data1 = np.genfromtxt("data/autoCorrTest11/size_0/autoCorr_10000.csv", delimiter=',')
data2 = np.genfromtxt("data/autoCorrTest11/size_1/autoCorr_10000.csv", delimiter=',')
data3 = np.genfromtxt("data/autoCorrTest11/size_2/autoCorr_10000.csv", delimiter=',')
data4 = np.genfromtxt("data/autoCorrTest11/size_3/autoCorr_10000.csv", delimiter=',')
for i in range(10100, 30000, 100):
    data1 = data1 + np.genfromtxt("data/autoCorrTest11/size_0/autoCorr_{}.csv".format(i), delimiter=',')
    data2 = data2 + np.genfromtxt("data/autoCorrTest11/size_1/autoCorr_{}.csv".format(i), delimiter=',')
    data3 = data3 + np.genfromtxt("data/autoCorrTest11/size_2/autoCorr_{}.csv".format(i), delimiter=',')
    data4 = data4 + np.genfromtxt("data/autoCorrTest11/size_3/autoCorr_{}.csv".format(i), delimiter=',')
data1 = data1/200
data2 = data2/200
data3 = data3/200
data4 = data4/200

# %%
r = np.arange(data2.shape[1])

# %%
fig1, ax1 = plt.subplots(facecolor="white")
ax1.plot(r[1:128], data1[80,1:128], label="Height = 256")
ax1.plot(r[1:128], data2[80,1:128], label="Height = 512")
ax1.plot(r[1:128], data3[80,1:128], label="Height = 640")
ax1.plot(r[1:128], data4[80,1:128], label="Height = 796")
ax1.axhline(0, linestyle='--', color='k')
ax1.set_xlabel(r'$r$')
ax1.set_ylabel(r'$\langle C(r)\rangle$')
#ax1.set_ylim(bottom=-0.05, top=0.125)
ax1.legend()

# %%
fig2, ax2 = plt.subplots(facecolor="white")
ax2.plot(r[1:128], np.log(data1[80,1:128]), label="Height = 256")
ax2.plot(r[1:128], np.log(data2[80,1:128]), label="Height = 512")
ax2.plot(r[1:128], np.log(data3[80,1:128]), label="Height = 640")
ax2.plot(r[1:128], np.log(data4[80,1:128]), label="Height = 796")
ax2.axhline(0, linestyle='--', color='k')
ax2.set_xlabel(r'$r$')
ax2.set_ylabel(r'$\langle C(r)\rangle$')
#ax2.set_ylim(bottom=-0.05, top=0.125)
ax2.legend()

# %%
x = np.arange(0, 40)
line1 = linregress(x, np.log(data1[80,1:41]))
line2 = linregress(x, np.log(data2[80,1:41]))
line3 = linregress(x, np.log(data3[80,1:41]))
line4 = linregress(x, np.log(data4[80,1:41]))

# %%
syst_size = np.array([256, 512, 640, 796])
corr_len = 1/np.abs(np.array([line1.slope, line2.slope, line3.slope, line4.slope]))

# %%
fig3, ax3 = plt.subplots(facecolor="white")
ax3.plot(syst_size, corr_len, label="Height = 256")

# %%
fig4, ax4 = plt.subplots(facecolor="white")
ax4.plot(r[1:128], data1[288,1:128], label="Height = 256")
ax4.plot(r[1:128], data2[288,1:128], label="Height = 512")
ax4.plot(r[1:128], data3[288,1:128], label="Height = 640")
ax4.plot(r[1:128], data4[288,1:128], label="Height = 796")
ax4.axhline(0, linestyle='--', color='k')
ax4.set_xlabel(r'$r$')
ax4.set_ylabel(r'$\langle C(r)\rangle$')
#ax4.set_ylim(bottom=-0.05, top=0.125)
ax4.legend()

# %%
fig5, ax5 = plt.subplots(facecolor="white")
ax5.plot(r[1:128], np.log(data1[288,1:128]), label="Height = 256")
ax5.plot(r[1:128], np.log(data2[288,1:128]), label="Height = 512")
ax5.plot(r[1:128], np.log(data3[288,1:128]), label="Height = 640")
ax5.plot(r[1:128], np.log(data4[288,1:128]), label="Height = 796")
ax5.axhline(0, linestyle='--', color='k')
ax5.set_xlabel(r'$r$')
ax5.set_ylabel(r'$\langle C(r)\rangle$')
#ax5.set_ylim(bottom=-0.05, top=0.125)
ax5.legend()

# %%
data5 = np.genfromtxt("data/autoCorrTest12/size_0/autoCorr_10000.csv", delimiter=',')
data6 = np.genfromtxt("data/autoCorrTest12/size_1/autoCorr_10000.csv", delimiter=',')
data7 = np.genfromtxt("data/autoCorrTest12/size_2/autoCorr_10000.csv", delimiter=',')
data8 = np.genfromtxt("data/autoCorrTest12/size_3/autoCorr_10000.csv", delimiter=',')
for i in range(10100, 30000, 100):
    data5 = data5 + np.genfromtxt("data/autoCorrTest12/size_0/autoCorr_{}.csv".format(i), delimiter=',')
    data6 = data6 + np.genfromtxt("data/autoCorrTest12/size_1/autoCorr_{}.csv".format(i), delimiter=',')
    data7 = data7 + np.genfromtxt("data/autoCorrTest12/size_2/autoCorr_{}.csv".format(i), delimiter=',')
    data8 = data8 + np.genfromtxt("data/autoCorrTest12/size_3/autoCorr_{}.csv".format(i), delimiter=',')
data5 = data5/200
data6 = data6/200
data7 = data7/200
data8 = data8/200

# %%
fig6, ax6 = plt.subplots(facecolor="white")
ax6.plot(r[1:128], data5[288,1:128], label="Height = 256")
ax6.plot(r[1:128], data6[288,1:128], label="Height = 512")
ax6.plot(r[1:128], data7[288,1:128], label="Height = 640")
ax6.plot(r[1:128], data8[288,1:128], label="Height = 796")
ax6.axhline(0, linestyle='--', color='k')
ax6.set_xlabel(r'$r$')
ax6.set_ylabel(r'$\langle C(r)\rangle$')
#ax6.set_ylim(bottom=-0.05, top=0.125)
ax6.legend()

# %%
x2 = np.arange(0, 40)
line5 = linregress(x, np.log(data5[288,1:41] + 0.03))
line6 = linregress(x, np.log(data6[288,1:41] + 0.03))
line7 = linregress(x, np.log(data7[288,1:41] + 0.03))
line8= linregress(x, np.log(data8[288,1:41] + 0.03))

# %%
syst_size = np.array([256, 512, 640, 796])
corr_len2 = 1/np.abs(np.array([line5.slope, line6.slope, line7.slope, line8.slope]))

# %%
fig7, ax7 = plt.subplots(facecolor="white")
ax7.plot(syst_size, corr_len2, label="Height = 256")

# %%
fig8, ax8 = plt.subplots(facecolor="white")
ax8.plot(r[1:128], np.log(data5[80,1:128]), label="Height = 256")
ax8.plot(r[1:128], np.log(data6[80,1:128]), label="Height = 512")
ax8.plot(r[1:128], np.log(data7[80,1:128]), label="Height = 640")
ax8.plot(r[1:128], np.log(data8[80,1:128]), label="Height = 796")
ax8.axhline(0, linestyle='--', color='k')
ax8.set_xlabel(r'$r$')
ax8.set_ylabel(r'$\langle C(r)\rangle$')
#ax2.set_ylim(bottom=-0.05, top=0.125)
ax8.legend()
# Out:
# /home/mlazarn/.local/lib/python3.7/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in log
#
# /home/mlazarn/.local/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: invalid value encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/mlazarn/.local/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in log
#   after removing the cwd from sys.path.

# %%
|
